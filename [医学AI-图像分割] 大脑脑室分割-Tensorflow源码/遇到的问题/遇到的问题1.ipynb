# %% [markdown]
# # keras 和 tensorflow 版本 必须匹配

# %% [markdown]
# https://stackoverflow.com/questions/62690377/tensorflow-compatibility-with-keras
#
# ![image.png](attachment:image.png)

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# ---------------------------------------------------------------------------
# AlreadyExistsError                        Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 from keras.preprocessing.image import ImageDataGenerator
#       4 datagen_train = ImageDataGenerator(rotation_range=15,
#       5                           width_shift_range=0.1,
#       6                           height_shift_range=0.1,
#       7                           zoom_range=0.2,
#       8                           rescale=1./255.0)
#      11 datagen_test = ImageDataGenerator(rescale=1./255.0)
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\__init__.py:25, in <module>
#      22 from keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from keras import models
#      27 from keras.engine.input_layer import Input
#      28 from keras.engine.sequential import Sequential
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\models.py:20, in <module>
#      18 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras import metrics as metrics_module
#      21 from keras import optimizer_v1
#      22 from keras.engine import functional
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\metrics.py:24, in <module>
#      21 from typing import List, Tuple, Union
#      22 import warnings
# ---> 24 from keras import activations
#      25 from keras import backend
#      26 from keras.engine import base_layer
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\activations.py:20, in <module>
#      17 import tensorflow.compat.v2 as tf
#      19 from keras import backend
# ---> 20 from keras.layers import advanced_activations
#      21 from keras.utils.generic_utils import deserialize_keras_object
#      22 from keras.utils.generic_utils import serialize_keras_object
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\layers\__init__.py:23, in <module>
#      20 from tensorflow.python import tf2
#      22 # Generic layers.
# ---> 23 from keras.engine.input_layer import Input
#      24 from keras.engine.input_layer import InputLayer
#      25 from keras.engine.input_spec import InputSpec
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\engine\input_layer.py:21, in <module>
#      19 from keras import backend
#      20 from keras.distribute import distributed_training_utils
# ---> 21 from keras.engine import base_layer
#      22 from keras.engine import keras_tensor
#      23 from keras.engine import node as node_module
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\engine\base_layer.py:43, in <module>
#      41 from keras.engine import node as node_module
#      42 from keras.mixed_precision import autocast_variable
# ---> 43 from keras.mixed_precision import loss_scale_optimizer
#      44 from keras.mixed_precision import policy
#      45 from keras.saving.saved_model import layer_serialization
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\mixed_precision\loss_scale_optimizer.py:18, in <module>
#      15 """Contains the loss scaling optimizer class."""
#      17 from keras import backend
# ---> 18 from keras import optimizers
#      19 from keras.mixed_precision import loss_scale as keras_loss_scale_module
#      20 from keras.optimizer_experimental import optimizer as optimizer_experimental
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\optimizers.py:31, in <module>
#      29 from keras.optimizer_v1 import Optimizer
#      30 from keras.optimizer_v1 import TFOptimizer
# ---> 31 from keras.optimizer_v2 import adadelta as adadelta_v2
#      32 from keras.optimizer_v2 import adagrad as adagrad_v2
#      33 from keras.optimizer_v2 import adam as adam_v2
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\optimizer_v2\adadelta.py:22, in <module>
#      20 import numpy as np
#      21 from keras import backend_config
# ---> 22 from keras.optimizer_v2 import optimizer_v2
#      23 from tensorflow.python.util.tf_export import keras_export
#      26 @keras_export('keras.optimizers.Adadelta')
#      27 class Adadelta(optimizer_v2.OptimizerV2):
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:36, in <module>
#      32 import tensorflow.compat.v2 as tf
#      33 from tensorflow.python.util.tf_export import keras_export
# ---> 36 keras_optimizers_gauge = tf.__internal__.monitoring.BoolGauge(
#      37     "/tensorflow/api/keras/optimizers", "keras optimizer usage", "method")
#      39 _DEFAULT_VALID_DTYPES = frozenset([
#      40     tf.float16, tf.bfloat16, tf.float32, tf.float64,
#      41     tf.complex64, tf.complex128
#      42 ])
#      45 def _deduplicate_indexed_slices(values, indices):
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\eager\monitoring.py:360, in BoolGauge.__init__(self, name, description, *labels)
#     352 def __init__(self, name, description, *labels):
#     353   """Creates a new BoolGauge.
#     354
#     355   Args:
#    (...)
#     358     *labels: The label list of the new metric.
#     359   """
# --> 360   super(BoolGauge, self).__init__('BoolGauge', _bool_gauge_methods,
#     361                                   len(labels), name, description, *labels)
#
# File ~\miniconda3\envs\tensorflow_env\lib\site-packages\tensorflow\python\eager\monitoring.py:135, in Metric.__init__(self, metric_name, metric_methods, label_length, *args)
#     131 if label_length >= len(self._metric_methods):
#     132   raise ValueError('Cannot create {} metric with label >= {}'.format(
#     133       self._metric_name, len(self._metric_methods)))
# --> 135 self._metric = self._metric_methods[self._label_length].create(*args)
#
# AlreadyExistsError: Another metric with the same name already exists.

# %% [markdown]
# # 缺啥装啥就行

# %%
#get next batch
image_batch = image_generator_train.next()
mask_batch = mask_generator_train.next()

#examine the output
print(image_batch.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #get next batch
# ----> 2 image_batch = image_generator_train.next()
#       3 mask_batch = mask_generator_train.next()
#       5 #examine the output
#
# File ~\miniconda3\envs\bilibili_env\lib\site-packages\keras\preprocessing\image.py:168, in Iterator.next(self)
#     165     index_array = next(self.index_generator)
#     166 # The transformation of images is not under thread lock
#     167 # so it can be done in parallel
# --> 168 return self._get_batches_of_transformed_samples(index_array)
#
# File ~\miniconda3\envs\bilibili_env\lib\site-packages\keras\preprocessing\image.py:384, in BatchFromFilesMixin._get_batches_of_transformed_samples(self, index_array)
#     382 if self.image_data_generator:
#     383     params = self.image_data_generator.get_random_transform(x.shape)
# --> 384     x = self.image_data_generator.apply_transform(x, params)
#     385     x = self.image_data_generator.standardize(x)
#     386 batch_x[i] = x
#
# File ~\miniconda3\envs\bilibili_env\lib\site-packages\keras\preprocessing\image.py:2013, in ImageDataGenerator.apply_transform(self, x, transform_parameters)
#    2010 img_col_axis = self.col_axis - 1
#    2011 img_channel_axis = self.channel_axis - 1
# -> 2013 x = apply_affine_transform(
#    2014     x,
#    2015     transform_parameters.get("theta", 0),
#    2016     transform_parameters.get("tx", 0),
#    2017     transform_parameters.get("ty", 0),
#    2018     transform_parameters.get("shear", 0),
#    2019     transform_parameters.get("zx", 1),
#    2020     transform_parameters.get("zy", 1),
#    2021     row_axis=img_row_axis,
#    2022     col_axis=img_col_axis,
#    2023     channel_axis=img_channel_axis,
#    2024     fill_mode=self.fill_mode,
#    2025     cval=self.cval,
#    2026     order=self.interpolation_order,
#    2027 )
#    2029 if transform_parameters.get("channel_shift_intensity") is not None:
#    2030     x = apply_channel_shift(
#    2031         x,
#    2032         transform_parameters["channel_shift_intensity"],
#    2033         img_channel_axis,
#    2034     )
#
# File ~\miniconda3\envs\bilibili_env\lib\site-packages\keras\preprocessing\image.py:2529, in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval, order)
#    2485 @keras_export("keras.preprocessing.image.apply_affine_transform")
#    2486 def apply_affine_transform(
#    2487     x,
#    (...)
#    2499     order=1,
#    2500 ):
#    2501     """Applies an affine transformation specified by the parameters given.
#    2502
#    2503     Args:
#    (...)
#    2527         ImportError: if SciPy is not available.
#    2528     """
# -> 2529     if scipy is None:
#    2530         raise ImportError(
#    2531             "Image transformations require SciPy. " "Install SciPy."
#    2532         )
#    2534     # Input sanity checks:
#    2535     # 1. x must 2D image with one or more channels (i.e., a 3D tensor)
#    2536     # 2. channels must be either first or last dimension
#
# NameError: name 'scipy' is not defined

# %%
! pip install scipy
! pip install pydot
! pip install graphviz
! pip install seaborn
