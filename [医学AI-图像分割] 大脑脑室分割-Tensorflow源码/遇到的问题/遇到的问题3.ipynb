# %% [markdown]
# # Kernel die
#
# 一到训练就die
#
# 我没直接解决这个问题，绕开这个问题，用了cpu

# %%
import tensorflow as tf
 
gpu_device_name = tf.test.gpu_device_name()
print(gpu_device_name)
# Out:
# /device:GPU:0

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\ziyif\AppData\Local\Temp\ipykernel_7736\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# ### 训练CNN时Jupiter notebook内核挂掉（Tensorflow）
#
# 如果你用了 ‘os.environ['KMP_DUPLICATE_LIB_OK']="TRUE" ’后还是挂掉的话，那多半是安装的packages之间互相冲突了。简单粗暴的弄一个新环境，只下载这个项目要用的包吧。
#
# https://blog.csdn.net/syyhaba/article/details/123749655

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
# 不管用

# %% [markdown]
# ### Could not locate zlibwapi.dll. Please make sure it is in your library path

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 可能的解决办法
# https://stackoverflow.com/questions/72356588/could-not-locate-zlibwapi-dll-please-make-sure-it-is-in-your-library-path
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 缺啥装啥

# %%
# Compile the model
optimizer = keras.optimizers.Adam()

loss = ['binary_crossentropy',dice_loss]
loss = ['binary_crossentropy',dice_loss]

metrics = ['binary_accuracy',dice_metric]

model.compile(loss=loss,
              optimizer=optimizer,
              metrics=metrics) 

# What does the finished model look like?
model.summary()
keras.utils.plot_model(model, show_shapes=True, rankdir='TD')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 160, 160, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 160, 160, 16  160         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 160, 160, 16  2320        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 80, 80, 16)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 80, 80, 32)   4640        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 80, 80, 32)   9248        ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 40, 40, 32)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 40, 40, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 40, 40, 64)   36928       ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 20, 20, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 20, 20, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 20, 20, 128)  147584      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 10, 10, 128)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 10, 10, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 10, 10, 256)  590080      ['conv2d_8[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 20, 20, 256)  0           ['conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 20, 20, 128)  131200      ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 20, 20, 256)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 20, 20, 128)  295040      ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 20, 20, 128)  147584      ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 40, 40, 128)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 40, 40, 64)   32832       ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 40, 40, 128)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 40, 40, 64)   73792       ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 40, 40, 64)   36928       ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 80, 80, 64)  0           ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 80, 80, 32)   8224        ['up_sampling2d_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 80, 80, 64)   0           ['conv2d_3[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 80, 80, 32)   18464       ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 80, 80, 32)   9248        ['conv2d_17[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 160, 160, 32  0          ['conv2d_18[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 160, 160, 16  2064        ['up_sampling2d_3[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 160, 160, 32  0           ['conv2d_1[0][0]',
#                                 )                                 'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 160, 160, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 160, 160, 16  2320        ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 160, 160, 1)  17          ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 1,940,817
# Trainable params: 1,940,817
# Non-trainable params: 0
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# Cannot find module cv2 when using OpenCV
pip install opencv-python
